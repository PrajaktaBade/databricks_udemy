# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("/Volumes/databricks_prajakta/bronze/bronze_volume/stores/")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("/Volumes/databricks_prajakta/bronze/jobvolume/raw/stores")
