# %%
with open("/Workspace/Databricks_Udemy_Tutorial/silver_layer/file.txt","r")as f: content = f.read()

print(content)

# %%
with open("/Workspace/Databricks_Udemy_Tutorial/silver_layer/file.txt","w")as f: f.write("I live in London")
