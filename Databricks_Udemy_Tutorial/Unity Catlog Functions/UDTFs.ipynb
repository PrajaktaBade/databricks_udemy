# %%
# %sql
create or replace function databricks_prajakta.bronze.udtf(p_para int)
returns table
return
(
  select * from databricks_prajakta.silver.sales_enr where total_amount > p_para 
)

# %%
# %sql
select * from databricks_prajakta.bronze.udtf(100)
