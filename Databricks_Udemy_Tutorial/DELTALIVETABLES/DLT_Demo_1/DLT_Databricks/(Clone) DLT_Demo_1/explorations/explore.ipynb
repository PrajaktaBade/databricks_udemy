# %%
df = spark.read.table("databricks_prajakta.silver.sales_enr")

# %%
display(df)

# %%
# %sql
create table databricks_prajakta.bronze.source(
  product_id int,
  product_name string,
  processDate timestamp
)

# %%
# %sql
insert into databricks_prajakta.bronze.source values
(1,'Honey',current_timestamp()),
(2,'milk',current_timestamp()),
(3,'bread',current_timestamp())

# %%
# %sql
select * from databricks_prajakta.dlt_schema.scd1_table

# %%
# %sql
select * from databricks_prajakta.dlt_schema.scd2_table

# %%
# %sql
insert into databricks_prajakta.bronze.source values
(1,'Honey',current_timestamp()),
(2,'milk',current_timestamp()),
(3,'multigrainBread',current_timestamp()),
(4,'mint',current_timestamp())

# %%
# %sql
select * from databricks_prajakta.dlt_schema.scd3_table
