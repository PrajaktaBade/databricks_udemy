# %%
dbutils.widgets.text("folder_name","")
dbutils.widgets.text("parent_folder_name","")

# %%
folder_name = dbutils.widgets.get("folder_name")
parent_folder_name = dbutils.widgets.get("parent_folder_name")

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
        .load(f"/Volumes/databricks_prajakta/bronze/bronze_volume/{folder_name}/")

# %%
df.write.format("delta")\
        .mode("overwrite")\
        .save(f"/Volumes/databricks_prajakta/bronze/jobvolume/{parent_folder_name}/{folder_name}/")
