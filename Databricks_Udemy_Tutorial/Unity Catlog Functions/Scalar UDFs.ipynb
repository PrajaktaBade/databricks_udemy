# %% [markdown]
# ### **SCALAR FUNCTIONS**

# %% [markdown]
# ### SQL

# %%
# %sql
create or replace function databricks_prajakta.bronze.sql_scalar_func(p_par int)
returns int
language sql
return p_par*10

# %%
# %sql
select databricks_prajakta.bronze.sql_scalar_func(total_amount) from databricks_prajakta.silver.sales_enr

# %% [markdown]
# ### PYTHON

# %%
# %sql
create or replace function databricks_prajakta.bronze.python_scalar_func(p_par int)
returns int
language python
as
$$
return p_par*20
$$

# %%
# %sql
select databricks_prajakta.bronze.python_scalar_func(total_amount) from databricks_prajakta.silver.sales_enr

# %%
# %sql
create or replace function databricks_prajakta.bronze.python_scalar_func_cust(p_par int)
returns string
language python
as
$$
  import requests
  response = requests.get(f".v.f.sl.s.lvsv.dv{p_par}").json()
  response_str = str(response)
  return response_str
$$
