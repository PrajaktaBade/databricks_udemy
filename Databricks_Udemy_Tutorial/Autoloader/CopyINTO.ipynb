# %%
# %sql
select * from parquet.`/Volumes/databricks_prajakta/bronze/autovol/copyinto/part-00000-tid-1800520145580676501-2fb00642-a896-4599-9957-2c7260f04aa7-132-1.c000.snappy.parquet`

# %%
# %sql
Drop table if exists databricks_prajakta.bronze.copyintotbl

# %%
# %sql
create table databricks_prajakta.bronze.copyintotbl
(
  order_id int,
  customer_id int,
  order_date date,
  order_amount double,
  order_status string
)

# %%
# %sql
copy into databricks_prajakta.bronze.copyintotbl
from "/Volumes/databricks_prajakta/bronze/autovol/copyinto/"
FILEFORMAT = PARQUET
FORMAT_OPTIONS  ('mergeSchema' = "True")
COPY_OPTIONS  ('mergeSchema' = "True")

# %%
# %sql
select * from databricks_prajakta.bronze.copyintotbl
